# %%
import pandas as pd
df=pd.read_excel("data.xlsx")
df
# Out:
#        day      city  temperature  windspeed   event
# 0   112017  new york           32          6    Rain
# 1   122017  new york           36          7   Sunny
# 2   132017  new york           28         12    Snow
# 3   142017  new york           33          7   Sunny
# 4   112017    mumbai           90          5   Sunny
# 5   122017    mumbai           85         12     Fog
# 6   132017    mumbai           87         15     Fog
# 7   142017    mumbai           92          5    Rain
# 8   112017     paris           45         20   Sunny
# 9   122017     paris           50         13  Cloudy
# 10  132017     paris           54          8  Cloudy
# 11  142017     paris           42         10  Cloudy

# %%
g=df.groupby('city')
g  #important ! group data and get aggregated data

# %%
for city, data in g:
    print("city:",city)
    print("\n")
    print("data:",data)
    
#sort y city name
g.get_group('mumbai') #only mumbai
# Out:
# city: mumbai
#
#
# data:       day    city  temperature  windspeed  event
# 4  112017  mumbai           90          5  Sunny
# 5  122017  mumbai           85         12    Fog
# 6  132017  mumbai           87         15    Fog
# 7  142017  mumbai           92          5   Rain
# city: new york
#
#
# data:       day      city  temperature  windspeed  event
# 0  112017  new york           32          6   Rain
# 1  122017  new york           36          7  Sunny
# 2  132017  new york           28         12   Snow
# 3  142017  new york           33          7  Sunny
# city: paris
#
#
# data:        day   city  temperature  windspeed   event
# 8   112017  paris           45         20   Sunny
# 9   122017  paris           50         13  Cloudy
# 10  132017  paris           54          8  Cloudy
# 11  142017  paris           42         10  Cloudy
#       day    city  temperature  windspeed  event
# 4  112017  mumbai           90          5  Sunny
# ...

# %%
g.max()
# Out:
#              day  temperature  windspeed  event
# city
# mumbai    142017           92         15  Sunny
# new york  142017           36         12  Sunny
# paris     142017           54         20  Sunny

# %%
g.mean()
# Out:
#                day  temperature  windspeed
# city
# mumbai    127017.0        88.50       9.25
# new york  127017.0        32.25       8.00
# paris     127017.0        47.75      12.75

# %%
g.describe()
# Out:
#            day                                                        \
#          count      mean           std       min       25%       50%
# city
# mumbai     4.0  127017.0  12909.944487  112017.0  119517.0  127017.0
# new york   4.0  127017.0  12909.944487  112017.0  119517.0  127017.0
# paris      4.0  127017.0  12909.944487  112017.0  119517.0  127017.0
#
#                              temperature         ...               windspeed  \
#                75%       max       count   mean  ...     75%   max     count
# city                                             ...
# mumbai    134517.0  142017.0         4.0  88.50  ...   90.50  92.0       4.0
# new york  134517.0  142017.0         4.0  32.25  ...   33.75  36.0       4.0
# paris     134517.0  142017.0         4.0  47.75  ...   51.00  54.0       4.0
#
#
#            mean       std  min   25%   50%    75%   max
# city
# mumbai     9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# ...

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
